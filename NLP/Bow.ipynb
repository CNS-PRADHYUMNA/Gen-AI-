# %%
# Bag of Words (BoW) Model

#reading the data
import pandas as pd

data = pd.read_csv("spam.csv",encoding="latin-1")

data = data[['v1', 'v2']]
data.columns = ['label', 'message']

data.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Data Preprocessing

import re
import nltk
from nltk.corpus import stopwords
# nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer


corpus=[]
for i in range(0, len(data)):
    review = re.sub('[^a-zA-Z]', ' ', data['message'][i])
    review = review.lower()
    review = review.split()
    
    lemmatizer = WordNetLemmatizer()
    review = [lemmatizer.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    
    review = ' '.join(review)
    corpus.append(review)

print(corpus[:5])
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat', 'ok lar joking wif u oni', 'free entry wkly comp win fa cup final tkts st may text fa receive entry question std txt rate c apply', 'u dun say early hor u c already say', 'nah think go usf life around though']

# %%
# Bow Model Creation

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,ngram_range=(1, 2))

X = cv.fit_transform(corpus).toarray()
y = data['label'].values

# %%
cv.vocabulary_
# Out:
# {'go': np.int64(1568),
#  'point': np.int64(3344),
#  'crazy': np.int64(888),
#  'available': np.int64(215),
#  'bugis': np.int64(426),
#  'great': np.int64(1671),
#  'world': np.int64(4877),
#  'la': np.int64(2121),
#  'cine': np.int64(706),
#  'got': np.int64(1643),
#  'wat': np.int64(4705),
#  'ok': np.int64(2935),
#  'lar': np.int64(2137),
#  'joking': np.int64(2051),
#  'wif': np.int64(4793),
#  'oni': np.int64(3002),
#  'ok lar': np.int64(2946),
#  'free': np.int64(1401),
#  'entry': np.int64(1194),
#  'wkly': np.int64(4848),
#  'comp': np.int64(803),
#  'win': np.int64(4803),
#  'fa': np.int64(1262),
#  'cup': np.int64(906),
#  'final': np.int64(1327),
#  'tkts': np.int64(4334),
#  'st': np.int64(4019),
#  'may': np.int64(2447),
#  'text': np.int64(4230),
#  'receive': np.int64(3541),
#  'question': np.int64(3460),
#  'std': np.int64(4044),
#  'txt': np.int64(4444),
#  'rate': np.int64(3491),
#  'apply': np.int64(151),
#  'free entry': np.int64(1410),
#  'entry wkly': np.int64(1197),
#  'wkly comp': np.int64(4849),
#  'cup final': np.int64(907),
#  'std txt': np.int64(4045),
#  'txt rate': np.int64(4456),
#  'rate apply': np.int64(3493),
#  'dun': np.int64(1123),
#  'say': np.int64(3698),
#  'early': np.int64(1137),
#  'already': np.int64(88),
#  'nah': np.int64(2677),
#  'think': np.int64(4273),
#  'usf': np.int64(4582),
#  'life': np.int64(2214),
#  'around': np.int64(173),
#  'though': np.int64(4289),
#  'think go': np.int64(4276),
#  'freemsg': np.int64(1431),
#  'hey': np.int64(1810),
#  'darling': np.int64(946),
#  'week': np.int64(4739),
#  'word': np.int64(4864),
#  'back': np.int64(244),
#  'like': np.int64(2226),
#  'fun': np.int64(1468),
#  'still': np.int64(4047),
#  'tb': np.int64(4189),
#  'xxx': np.int64(4934),
#  'send': np.int64(3756),
#  'rcv': np.int64(3499),
#  'freemsg hey': np.int64(1432),
#  'like fun': np.int64(2228),
#  'even': np.int64(1217),
#  'brother': np.int64(411),
#  'speak': np.int64(3987),
#  'treat': np.int64(4408),
#  'per': np.int64(3169),
#  'request': np.int64(3606),
#  'melle': np.int64(2475),
#  'oru': np.int64(3053),
#  'minnaminunginte': np.int64(2527),
#  'nurungu': np.int64(2875),
#  'vettam': np.int64(4607),
#  'set': np.int64(3798),
#  'callertune': np.int64(506),
#  'caller': np.int64(503),
#  'press': np.int64(3399),
#  'copy': np.int64(856),
#  'friend': np.int64(1441),
#  'per request': np.int64(3176),
#  'request melle': np.int64(3607),
#  'melle melle': np.int64(2476),
#  'melle oru': np.int64(2477),
#  'oru minnaminunginte': np.int64(3054),
#  'minnaminunginte nurungu': np.int64(2528),
#  'nurungu vettam': np.int64(2876),
#  'vettam set': np.int64(4608),
#  'set callertune': np.int64(3799),
#  'callertune caller': np.int64(507),
#  'caller press': np.int64(504),
#  'press copy': np.int64(3400),
#  'copy friend': np.int64(857),
#  'friend callertune': np.int64(1442),
#  'winner': np.int64(4821),
#  'valued': np.int64(4596),
#  'network': np.int64(2722),
#  'customer': np.int64(915),
#  'selected': np.int64(3748),
#  'prize': np.int64(3416),
#  'reward': np.int64(3628),
#  'claim': np.int64(712),
#  'call': np.int64(453),
#  'code': np.int64(750),
#  'valid': np.int64(4591),
#  'hour': np.int64(1894),
#  'winner valued': np.int64(4823),
#  'valued network': np.int64(4598),
#  'network customer': np.int64(2723),
#  'claim call': np.int64(713),
#  'call claim': np.int64(459),
#  'claim code': np.int64(714),
#  'valid hour': np.int64(4592),
#  'mobile': np.int64(2562),
#  'month': np.int64(2595),
#  'entitled': np.int64(1192),
#  'update': np.int64(4507),
#  'latest': np.int64(2155),
#  'colour': np.int64(770),
#  'camera': np.int64(518),
#  'co': np.int64(744),
#  'entitled update': np.int64(1193),
#  'update latest': np.int64(4509),
#  'latest colour': np.int64(2157),
#  'free call': np.int64(1405),
#  'call mobile': np.int64(480),
#  'mobile update': np.int64(2575),
#  'update co': np.int64(4508),
#  'co free': np.int64(745),
#  'gonna': np.int64(1615),
#  'home': np.int64(1859),
#  'soon': np.int64(3954),
#  'want': np.int64(4684),
#  'talk': np.int64(4179),
#  'stuff': np.int64(4094),
#  'anymore': np.int64(132),
#  'tonight': np.int64(4383),
#  'enough': np.int64(1185),
#  'today': np.int64(4345),
#  'want talk': np.int64(4696),
#  'six': np.int64(3878),
#  'chance': np.int64(622),
#  'cash': np.int64(570),
#  'pound': np.int64(3374),
#  'cost': np.int64(861),
#  'day': np.int64(955),
#  'reply': np.int64(3586),
#  'hl': np.int64(1835),
#  'info': np.int64(1973),
#  'chance win': np.int64(627),
#  'win cash': np.int64(4804),
#  'cash pound': np.int64(582),
#  'reply hl': np.int64(3591),
#  'hl info': np.int64(1836),
#  'urgent': np.int64(4558),
#  'membership': np.int64(2480),
#  'www': np.int64(4909),
#  'net': np.int64(2716),
#  'pobox': np.int64(3336),
#  'ldnw': np.int64(2177),
#  'week free': np.int64(4742),
#  'txt word': np.int64(4462),
#  'claim www': np.int64(722),
#  'searching': np.int64(3722),
#  'right': np.int64(3631),
#  'thank': np.int64(4255),
#  'promise': np.int64(3434),
#  'wont': np.int64(4862),
#  'take': np.int64(4168),
#  'help': np.int64(1807),
#  'wonderful': np.int64(4860),
#  'blessing': np.int64(341),
#  'time': np.int64(4311),
#  'date': np.int64(951),
#  'sunday': np.int64(4121),
#  'use': np.int64(4575),
#  'credit': np.int64(892),
#  'click': np.int64(731),
#  'wap': np.int64(4701),
#  'link': np.int64(2245),
#  'next': np.int64(2756),
#  'message': np.int64(2486),
#  'http': np.int64(1906),
#  'com': np.int64(774),
#  'oh': np.int64(2914),
#  'watching': np.int64(4712),
#  'eh': np.int64(1156),
#  'remember': np.int64(3572),
#  'spell': np.int64(4003),
#  'name': np.int64(2679),
#  'yes': np.int64(4961),
#  'naughty': np.int64(2693),
#  'make': np.int64(2392),
#  'wet': np.int64(4775),
#  'fine': np.int64(1337),
#  'way': np.int64(4719),
#  'feel': np.int64(1299),
#  'england': np.int64(1180),
#  'dont': np.int64(1077),
#  'miss': np.int64(2537),
#  'goal': np.int64(1594),
#  'team': np.int64(4197),
#  'news': np.int64(2752),
#  'ur': np.int64(4515),
#  'national': np.int64(2688),
#  'eg': np.int64(1154),
#  'try': np.int64(4422),
#  'wale': np.int64(4667),
#  'scotland': np.int64(3712),
#  'wq': np.int64(4895),
#  'dont miss': np.int64(1085),
#  'txt ur': np.int64(4461),
#  'seriously': np.int64(3789),
#  'going': np.int64(1601),
#  'ha': np.int64(1729),
#  'ha ha': np.int64(1730),
#  'pay': np.int64(3137),
#  'first': np.int64(1346),
#  'da': np.int64(930),
#  'stock': np.int64(4056),
#  'comin': np.int64(797),
#  'aft': np.int64(53),
#  'finish': np.int64(1341),
#  'lunch': np.int64(2362),
#  'str': np.int64(4083),
#  'lor': np.int64(2293),
#  'ard': np.int64(160),
#  'smth': np.int64(3920),
#  'ard smth': np.int64(162),
#  'finish ur': np.int64(1342),
#  'alright': np.int64(90),
#  'meet': np.int64(2464),
#  'sooner': np.int64(3955),
#  'eat': np.int64(1145),
#  'slice': np.int64(3898),
#  'really': np.int64(3526),
#  'hungry': np.int64(1913),
#  'tho': np.int64(4288),
#  'suck': np.int64(4111),
#  'mark': np.int64(2425),
#  'getting': np.int64(1540),
#  'worried': np.int64(4881),
#  'know': np.int64(2101),
#  'sick': np.int64(3849),
#  'turn': np.int64(4436),
#  'pizza': np.int64(3270),
#  'lol': np.int64(2276),
#  'getting worried': np.int64(1542),
#  'always': np.int64(93),
#  'catch': np.int64(593),
#  'bus': np.int64(431),
#  'frying': np.int64(1459),
#  'egg': np.int64(1155),
#  'tea': np.int64(4194),
#  'eating': np.int64(1148),
#  'mom': np.int64(2588),
#  'left': np.int64(2190),
#  'dinner': np.int64(1041),
#  'love': np.int64(2320),
#  'amp': np.int64(101),
#  'car': np.int64(535),
#  'let': np.int64(2202),
#  'room': np.int64(3650),
#  'let know': np.int64(2205),
#  'work': np.int64(4870),
#  'feel like': np.int64(1305),
#  'wait': np.int64(4653),
#  'clear': np.int64(729),
#  'sure': np.int64(4139),
#  'live': np.int64(2255),
#  'yeah': np.int64(4947),
#  'child': np.int64(687),
#  'caught': np.int64(595),
#  'till': np.int64(4307),
#  'cheer': np.int64(678),
#  'yeah got': np.int64(4949),
#  'tell': np.int64(4206),
#  'anything': np.int64(135),
#  'tell anything': np.int64(4207),
#  'fear': np.int64(1294),
#  'quick': np.int64(3465),
#  'thanks': np.int64(4258),
#  'subscription': np.int64(4107),
#  'ringtone': np.int64(3635),
#  'uk': np.int64(4477),
#  'charged': np.int64(641),
#  'please': np.int64(3298),
#  'confirm': np.int64(821),
#  'replying': np.int64(3601),
#  'mobile charged': np.int64(2564),
#  'yup': np.int64(4991),
#  'look': np.int64(2286),
#  'timing': np.int64(4329),
#  'msg': np.int64(2630),
#  'xuhui': np.int64(4931),
#  'learn': np.int64(2183),
#  'nd': np.int64(2694),
#  'lesson': np.int64(2201),
#  'yup ok': np.int64(4992),
#  'ok go': np.int64(2942),
#  'go home': np.int64(1578),
#  'oops': np.int64(3009),
#  'roommate': np.int64(3652),
#  'done': np.int64(1076),
#  'see': np.int64(3732),
#  'letter': np.int64(2208),
#  'decide': np.int64(992),
#  'anything lor': np.int64(137),
#  'hello': np.int64(1801),
#  'saturday': np.int64(3689),
#  'texting': np.int64(4246),
#  'decided': np.int64(993),
#  'tomo': np.int64(4368),
#  'trying': np.int64(4424),
#  'invite': np.int64(1996),
#  'pls': np.int64(3310),
#  'ahead': np.int64(65),
#  'wanted': np.int64(4698),
#  'weekend': np.int64(4748),
#  'abiola': np.int64(6),
#  'great weekend': np.int64(1680),
#  'forget': np.int64(1384),
#  'need': np.int64(2701),
#  'crave': np.int64(887),
#  'sweet': np.int64(4150),
#  'yummy': np.int64(4984),
#  'want need': np.int64(4690),
#  'need crave': np.int64(2706),
#  'burn': np.int64(430),
#  'tried': np.int64(4411),
#  'sm': np.int64(3903),
#  'nokia': np.int64(2804),
#  'camcorder': np.int64(511),
#  'delivery': np.int64(1008),
#  'tomorrow': np.int64(4369),
#  'tried call': np.int64(4412),
#  'call reply': np.int64(490),
#  'reply sm': np.int64(3596),
#  'free nokia': np.int64(1418),
#  'nokia mobile': np.int64(2813),
#  'mobile free': np.int64(2568),
#  'free camcorder': np.int64(1406),
#  'please call': np.int64(3300),
#  'call delivery': np.int64(464),
#  'delivery tomorrow': np.int64(1009),
#  'seeing': np.int64(3741),
#  'hope': np.int64(1873),
#  'man': np.int64(2405),
#  'well': np.int64(4758),
#  'lt': np.int64(2351),
#  'gt': np.int64(1688),
#  'inch': np.int64(1962),
#  'hope like': np.int64(1880),
#  'lt gt': np.int64(2353),
#  'gt inch': np.int64(1696),
#  'missed': np.int64(2543),
#  'call message': np.int64(477),
#  'message missed': np.int64(2490),
#  'missed call': np.int64(2544),
#  'get': np.int64(1511),
#  'nigeria': np.int64(2778),
#  'fair': np.int64(1267),
#  'hopefully': np.int64(1885),
#  'tyler': np.int64(4471),
#  'could': np.int64(867),
#  'maybe': np.int64(2451),
#  'ask': np.int64(186),
#  'bit': np.int64(328),
#  'hospital': np.int64(1889),
#  'kept': np.int64(2080),
#  'telling': np.int64(4212),
#  'weak': np.int64(4729),
#  'want go': np.int64(4687),
#  'saw': np.int64(3697),
#  'class': np.int64(725),
#  'first time': np.int64(1349),
#  'gram': np.int64(1667),
#  'usually': np.int64(4586),
#  'run': np.int64(3663),
#  'half': np.int64(1740),
#  'almost': np.int64(85),
#  'whole': np.int64(4788),
#  'second': np.int64(3726),
#  'like lt': np.int64(2232),
#  'fyi': np.int64(1471),
#  'ride': np.int64(3630),
#  'morning': np.int64(2607),
#  'place': np.int64(3271),
#  'early tomorrow': np.int64(1138),
#  'tomorrow morning': np.int64(4371),
#  'wow': np.int64(4892),
#  'never': np.int64(2729),
#  'realized': np.int64(3525),
#  'embarassed': np.int64(1167),
#  'thought': np.int64(4290),
#  'liked': np.int64(2238),
#  'since': np.int64(3863),
#  'best': np.int64(302),
#  'seemed': np.int64(3744),
#  'happy': np.int64(1764),
#  'sorry': np.int64(3958),
#  'give': np.int64(1556),
#  'ac': np.int64(13),
#  'new': np.int64(2730),
#  'red': np.int64(3551),
#  'play': np.int64(3289),
#  'ice': np.int64(1930),
#  'correct': np.int64(859),
#  'end': np.int64(1170),
#  'sm ac': np.int64(3904),
#  'reply end': np.int64(3590),
#  'yesterday': np.int64(4969),
#  'find': np.int64(1330),
#  'url': np.int64(4570),
#  'lt url': np.int64(2355),
#  'url gt': np.int64(4571),
#  'congrats': np.int64(823),
#  'year': np.int64(4953),
#  'special': np.int64(3990),
#  'cinema': np.int64(707),
#  'pas': np.int64(3122),
#  'suprman': np.int64(4136),
#  'matrix': np.int64(2438),
#  'starwars': np.int64(4037),
#  'etc': np.int64(1212),
#  'bx': np.int64(442),
#  'ip': np.int64(2005),
#  'pm': np.int64(3329),
#  'congrats year': np.int64(825),
#  'year special': np.int64(4956),
#  'special cinema': np.int64(3993),
#  'cinema pas': np.int64(708),
#  'pas call': np.int64(3123),
#  'call suprman': np.int64(494),
#  'suprman matrix': np.int64(4137),
#  'matrix starwars': np.int64(2439),
#  'starwars etc': np.int64(4038),
#  'etc free': np.int64(1213),
#  'free bx': np.int64(1404),
#  'bx ip': np.int64(443),
#  'ip pm': np.int64(2006),
#  'pm dont': np.int64(3331),
#  'later': np.int64(2152),
#  'meeting': np.int64(2470),
#  'sorry call': np.int64(3959),
#  'call later': np.int64(476),
#  'later meeting': np.int64(2153),
#  'reached': np.int64(3507),
#  'odi': np.int64(2890),
#  'series': np.int64(3787),
#  'pick': np.int64(3237),
#  'burger': np.int64(429),
#  'move': np.int64(2620),
#  'pain': np.int64(3082),
#  'way home': np.int64(4722),
#  'good': np.int64(1619),
#  'joke': np.int64(2049),
#  'girl': np.int64(1549),
#  'situation': np.int64(3876),
#  'part': np.int64(3109),
#  'checking': np.int64(676),
#  'iq': np.int64(2010),
#  'part checking': np.int64(3110),
#  'checking iq': np.int64(677),
#  'took': np.int64(4386),
#  'forever': np.int64(1382),
#  'come': np.int64(779),
#  'ok come': np.int64(2939),
#  'double': np.int64(1094),
#  'check': np.int64(671),
#  'hair': np.int64(1737),
#  'dresser': np.int64(1107),
#  'said': np.int64(3675),
#  'wun': np.int64(4908),
#  'cut': np.int64(921),
#  'short': np.int64(3829),
#  'nice': np.int64(2769),
#  'hair dresser': np.int64(1738),
#  'cut short': np.int64(922),
#  'pleased': np.int64(3306),
#  'advise': np.int64(46),
#  'following': np.int64(1371),
#  'recent': np.int64(3547),
#  'review': np.int64(3626),
#  'mob': np.int64(2557),
#  'awarded': np.int64(228),
#  'bonus': np.int64(358),
#  'valued customer': np.int64(4597),
#  'customer pleased': np.int64(919),
#  'pleased advise': np.int64(3307),
#  'advise following': np.int64(47),
#  'following recent': np.int64(1372),
#  'recent review': np.int64(3548),
#  'review mob': np.int64(3627),
#  'mob awarded': np.int64(2558),
#  'awarded bonus': np.int64(229),
#  'bonus prize': np.int64(361),
#  'prize call': np.int64(3417),
#  'song': np.int64(3948),
#  'valuable': np.int64(4594),
#  'frnds': np.int64(1455),
#  'rply': np.int64(3658),
#  'send ur': np.int64(3773),
#  'complimentary': np.int64(810),
#  'trip': np.int64(4414),
#  'dis': np.int64(1048),
#  'urgent ur': np.int64(4566),
#  'ur awarded': np.int64(4518),
#  'hear': np.int64(1785),
#  'plane': np.int64(3283),
#  'month end': np.int64(2596),
#  'wah': np.int64(4652),
#  'lucky': np.int64(2359),
#  'save': np.int64(3695),
#  'money': np.int64(2592),
#  'hee': np.int64(1796),
#  'finished': np.int64(1343),
#  'hi': np.int64(1817),
#  'babe': np.int64(238),
#  'im': np.int64(1943),
#  'wanna': np.int64(4680),
#  'something': np.int64(3941),
#  'xx': np.int64(4932),
#  'hi babe': np.int64(1818),
#  'im home': np.int64(1947),
#  'waiting': np.int64(4660),
#  'machan': np.int64(2374),
#  'call free': np.int64(465),
#  'thats': np.int64(4264),
#  'cool': np.int64(854),
#  'gentleman': np.int64(1504),
#  'dignity': np.int64(1038),
#  'respect': np.int64(3609),
#  'thats cool': np.int64(4265),
#  'gentleman treat': np.int64(1505),
#  'treat dignity': np.int64(4409),
#  'dignity respect': np.int64(1039),
#  'people': np.int64(3162),
#  'much': np.int64(2653),
#  'shy': np.int64(3846),
#  'pa': np.int64(3074),
#  'looking': np.int64(2290),
#  'job': np.int64(2041),
#  'ta': np.int64(4165),
#  'ah': np.int64(63),
#  'ok way': np.int64(2962),
#  'hi hi': np.int64(1822),
#  'place man': np.int64(3277),
#  'stop': np.int64(4063),
#  'urgnt': np.int64(4569),
#  'real': np.int64(3517),
#  'yo': np.int64(4975),
#  'ticket': np.int64(4303),
#  'one': np.int64(2979),
#  'used': np.int64(4579),
#  'started': np.int64(4034),
#  'came': np.int64(513),
#  'bed': np.int64(286),
#  'coin': np.int64(755),
#  'gotta': np.int64(1660),
#  'nitros': np.int64(2796),
#  'came back': np.int64(514),
#  'cash nitros': np.int64(580),
#  'still tonight': np.int64(4053),
#  'kano': np.int64(2068),
#  'il': np.int64(1939),
#  'download': np.int64(1097),
#  'wen': np.int64(4764),
#  'wen ur': np.int64(4766),
#  'stand': np.int64(4026),
#  'close': np.int64(735),
#  'another': np.int64(120),
#  'night': np.int64(2779),
#  'spent': np.int64(4006),
#  'late': np.int64(2150),
#  'afternoon': np.int64(55),
#  'mean': np.int64(2453),
#  'moro': np.int64(2613),
#  'sheet': np.int64(3817),
#  'smile': np.int64(3911),
#  'pleasure': np.int64(3308),
#  'trouble': np.int64(4415),
#  'rain': np.int64(3479),
#  'sum': np.int64(4116),
#  'hurt': np.int64(1917),
#  'becoz': np.int64(285),
#  'someone': np.int64(3935),
#  'smiling': np.int64(3914),
#  'pain smile': np.int64(3086),
#  'like rain': np.int64(2235),
#  'love see': np.int64(2331),
#  'service': np.int64(3791),
#  'representative': np.int64(3603),
#  'guaranteed': np.int64(1708),
#  'call customer': np.int64(462),
#  'customer service': np.int64(920),
#  'service representative': np.int64(3796),
#  'representative pm': np.int64(3605),
#  'pm guaranteed': np.int64(3332),
#  'guaranteed cash': np.int64(1711),
#  'cash prize': np.int64(583),
#  'havent': np.int64(1778),
#  'planning': np.int64(3288),
#  'buy': np.int64(436),
#  'lido': np.int64(2212),
#  'show': np.int64(3837),
#  'collected': np.int64(764),
#  'simply': np.int64(3862),
#  'password': np.int64(3128),
#  'mix': np.int64(2550),
#  'verify': np.int64(4604),
#  'fml': np.int64(1368),
#  'free ringtone': np.int64(1421),
#  'password mix': np.int64(3131),
#  'movie': np.int64(2622),
#  'abt': np.int64(10),
#  'wat abt': np.int64(4706),
#  'load': np.int64(2263),
#  'loan': np.int64(2264),
#  'wk': np.int64(4843),
#  'hols': np.int64(1858),
#  'forgot': np.int64(1386),
#  'appointment': np.int64(153),
#  'four': np.int64(1397),
#  'shower': np.int64(3841),
#  'cause': np.int64(596),
#  'prob': np.int64(3424),
#  'ham': np.int64(1746),
#  'need get': np.int64(2708),
#  'get home': np.int64(1522),
#  'nothing': np.int64(2839),
#  'else': np.int64(1162),
#  'okay': np.int64(2965),
#  'price': np.int64(3407),
#  'long': np.int64(2282),
#  'legal': np.int64(2193),
#  'ave': np.int64(217),
#  'gone': np.int64(1614),
#  'driving': np.int64(1112),
#  'test': np.int64(4229),
#  'yet': np.int64(4970),
#  'guess': np.int64(1721),
#  'gave': np.int64(1488),
#  'boston': np.int64(375),
#  'men': np.int64(2481),
#  'changed': np.int64(632),
#  'search': np.int64(3720),
#  'location': np.int64(2267),
#  'nyc': np.int64(2884),
#  'cuz': np.int64(927),
#  'page': np.int64(3080),
#  'umma': np.int64(4482),
#  'vava': np.int64(4601),
#  'lot': np.int64(2310),
#  'dear': np.int64(979),
#  'love lot': np.int64(2328),
#  'wish': np.int64(4827),
#  'birthday': np.int64(323),
#  'making': np.int64(2401),
#  'truly': np.int64(4418),
#  'aight': np.int64(67),
#  'hit': np.int64(1833),
#  'get cash': np.int64(1515),
#  'would': np.int64(4888),
#  'address': np.int64(39),
#  'considering': np.int64(831),
#  'computer': np.int64(813),
#  'old': np.int64(2973),
#  'better': np.int64(308),
#  'always one': np.int64(95),
#  'worry': np.int64(4882),
#  'busy': np.int64(434),
#  'dont worry': np.int64(1091),
#  'noun': np.int64(2848),
#  'research': np.int64(3608),
#  'going dinner': np.int64(1604),
#  'thing': np.int64(4271),
#  'scared': np.int64(3705),
#  'mah': np.int64(2383),
#  'loud': np.int64(2314),
#  'dun like': np.int64(1127),
#  'contact': np.int64(833),
#  'last': np.int64(2141),
#  'draw': np.int64(1099),
#  'hr': np.int64(1904),
#  'ppm': np.int64(3386),
#  'trying contact': np.int64(4425),
#  'contact last': np.int64(837),
#  'last weekend': np.int64(2148),
#  'weekend draw': np.int64(4750),
#  'draw show': np.int64(1101),
#  'show prize': np.int64(3838),
#  'prize guaranteed': np.int64(3421),
#  'guaranteed call': np.int64(1710),
#  'code valid': np.int64(753),
#  'valid hr': np.int64(4593),
#  'hr ppm': np.int64(1905),
#  'wa': np.int64(4651),
#  'sentence': np.int64(3784),
#  'anyway': np.int64(142),
#  'juz': np.int64(2064),
#  'tt': np.int64(4432),
#  'eatin': np.int64(1147),
#  'weight': np.int64(4754),
#  'haha': np.int64(1732),
#  'anythin': np.int64(134),
#  'happened': np.int64(1759),
#  'entered': np.int64(1188),
#  'cabin': np.int64(445),
#  'bos': np.int64(373),
#  'felt': np.int64(1310),
#  'askd': np.int64(190),
#  'invited': np.int64(1997),
#  'apartment': np.int64(146),
#  'went': np.int64(4767),
#  'entered cabin': np.int64(1189),
#  'cabin pa': np.int64(446),
#  'pa said': np.int64(3076),
#  'said happy': np.int64(3676),
#  'happy day': np.int64(1767),
#  'day bos': np.int64(959),
#  'bos felt': np.int64(374),
#  'felt special': np.int64(1311),
#  'special askd': np.int64(3991),
#  'askd lunch': np.int64(191),
#  'lunch lunch': np.int64(2364),
#  'lunch invited': np.int64(2363),
#  'invited apartment': np.int64(1998),
#  'apartment went': np.int64(147),
#  'specially': np.int64(3999),
#  'holiday': np.int64(1851),
#  'flight': np.int64(1362),
#  'inc': np.int64(1960),
#  'operator': np.int64(3014),
#  'min': np.int64(2510),
#  'winner specially': np.int64(4822),
#  'specially selected': np.int64(4000),
#  'selected receive': np.int64(3749),
#  'holiday flight': np.int64(1854),
#  'flight inc': np.int64(1363),
#  'inc speak': np.int64(1961),
#  'speak live': np.int64(3988),
#  'live operator': np.int64(2259),
#  'operator claim': np.int64(3015),
#  'must': np.int64(2672),
#  'friday': np.int64(1439),
#  'needed': np.int64(2713),
#  'hmm': np.int64(1838),
#  'uncle': np.int64(4488),
#  'informed': np.int64(1979),
#  'paying': np.int64(3144),
#  'school': np.int64(3709),
#  'directly': np.int64(1046),
#  'food': np.int64(1374),
#  'buy food': np.int64(438),
#  'private': np.int64(3414),
#  'account': np.int64(22),
#  'statement': np.int64(4039),
#  'unredeemed': np.int64(4500),
#  'identifier': np.int64(1933),
#  'expires': np.int64(1256),
#  'private account': np.int64(3415),
#  'account statement': np.int64(25),
#  'statement show': np.int64(4040),
#  'show unredeemed': np.int64(3840),
#  'unredeemed bonus': np.int64(4501),
#  'bonus point': np.int64(360),
#  'point claim': np.int64(3346),
#  'call identifier': np.int64(472),
#  'identifier code': np.int64(1934),
#  'code expires': np.int64(751),
#  'landline': np.int64(2131),
#  'box': np.int64(382),
#  'urgent mobile': np.int64(4562),
#  'mobile awarded': np.int64(2563),
#  'bonus caller': np.int64(359),
#  'caller prize': np.int64(505),
#  'prize final': np.int64(3420),
#  'contact call': np.int64(834),
#  'call landline': np.int64(475),
#  'voda': np.int64(4628),
#  'number': np.int64(2861),
#  'ending': np.int64(1174),
#  'award': np.int64(224),
#  'match': np.int64(2432),
#  'quoting': np.int64(3473),
#  'standard': np.int64(4027),
#  'app': np.int64(149),
#  'today voda': np.int64(4357),
#  'voda number': np.int64(4629),
#  'number ending': np.int64(2865),
#  'ending selected': np.int64(1175),
#  'receive award': np.int64(3542),
#  'award match': np.int64(226),
#  'match please': np.int64(2433),
#  'call quoting': np.int64(489),
#  'quoting claim': np.int64(3474),
#  'code standard': np.int64(752),
#  'standard rate': np.int64(4028),
#  'rate app': np.int64(3492),
#  'mu': np.int64(2652),
#  'buying': np.int64(439),
#  'wat time': np.int64(4708),
#  'time finish': np.int64(4314),
#  'yetunde': np.int64(4972),
#  'sent': np.int64(3778),
#  'bother': np.int64(376),
#  'sending': np.int64(3776),
#  'apologise': np.int64(148),
#  'sent text': np.int64(3781),
#  'del': np.int64(1001),
#  'bak': np.int64(254),
#  'hope well': np.int64(1884),
#  'long time': np.int64(2284),
#  'time give': np.int64(4316),
#  'give call': np.int64(1559),
#  'dear call': np.int64(981),
#  'answer': np.int64(125),
#  'answer question': np.int64(127),
#  'sunshine': np.int64(4126),
#  'quiz': np.int64(3469),
#  'top': np.int64(4389),
#  'sony': np.int64(3950),
#  'dvd': np.int64(1133),
#  'player': np.int64(3294),
#  'country': np.int64(872),
#  'ansr': np.int64(123),
#  'sp': np.int64(3982),
#  'tyrone': np.int64(4474),
#  'sunshine quiz': np.int64(4127),
#  'quiz wkly': np.int64(3471),
#  'wkly win': np.int64(4851),
#  'win top': np.int64(4813),
#  'top sony': np.int64(4390),
#  'sony dvd': np.int64(3951),
#  'dvd player': np.int64(1134),
#  'player know': np.int64(3295),
#  'know country': np.int64(2103),
#  'txt ansr': np.int64(4445),
#  'ansr sp': np.int64(124),
#  'sp tyrone': np.int64(3983),
#  'laid': np.int64(2127),
#  'dogging': np.int64(1070),
#  'direct': np.int64(1043),
#  'join': np.int64(2046),
#  'largest': np.int64(2139),
#  'bt': np.int64(417),
#  'txting': np.int64(4467),
#  'nt': np.int64(2850),
#  'ec': np.int64(1149),
#  'want get': np.int64(4686),
#  'get laid': np.int64(1524),
#  'tonight want': np.int64(4384),
#  'want real': np.int64(4693),
#  'real dogging': np.int64(3519),
#  'dogging location': np.int64(1071),
#  'location sent': np.int64(2268),
#  'sent direct': np.int64(3779),
#  'direct ur': np.int64(1045),
#  'ur mob': np.int64(4540),
#  'join uk': np.int64(2047),
#  'uk largest': np.int64(4479),
#  'largest dogging': np.int64(2140),
#  'dogging network': np.int64(1072),
#  'haf': np.int64(1731),
#  'yijue': np.int64(4973),
#  'befor': np.int64(290),
#  'activity': np.int64(31),
#  'check room': np.int64(673),
#  'room befor': np.int64(3651),
#  'befor activity': np.int64(291),
#  'chat': np.int64(650),
#  'hardcore': np.int64(1773),
#  'age': np.int64(59),
#  'yr': np.int64(4981),
#  'go get': np.int64(1576),
#  'lazy': np.int64(2170),
#  'type': np.int64(4472),
#  'lect': np.int64(2188),
#  'text way': np.int64(4241),
#  'sir': np.int64(3868),
#  'mail': np.int64(2387),
#  'sir waiting': np.int64(3870),
#  'swt': np.int64(4159),
#  'tired': np.int64(4330),
#  'little': np.int64(2252),
#  'lovable': np.int64(2317),
#  'person': np.int64(3184),
#  'coz': np.int64(878),
#  'occupy': np.int64(2889),
#  'biggest': np.int64(315),
#  'heart': np.int64(1788),
#  'gud': np.int64(1714),
#  'ni': np.int64(2765),
#  'little thing': np.int64(2254),
#  'gud ni': np.int64(1718),
#  'open': np.int64(3011),
#  'ya': np.int64(4940),
#  'dot': np.int64(1093),
#  'yes see': np.int64(4967),
#  'see ya': np.int64(3740),
#  'whats': np.int64(4778),
#  'staff': np.int64(4024),
#  'taking': np.int64(4177),
#  'replied': np.int64(3585),
#  'sexy': np.int64(3805),
#  'female': np.int64(1312),
#  'local': np.int64(2266),
#  'luv': np.int64(2366),
#  'netcollex': np.int64(2720),
#  'ltd': np.int64(2356),
#  'netcollex ltd': np.int64(2721),
#  'per msg': np.int64(3174),
#  'msg reply': np.int64(2639),
#  'reply stop': np.int64(3597),
#  'stop end': np.int64(4066),
#  'begin': np.int64(292),
#  'qatar': np.int64(3454),
#  'pray': np.int64(3393),
#  'hard': np.int64(1772),
#  'deleted': np.int64(1003),
#  'birla': np.int64(320),
#  'soft': np.int64(3928),
#  'got job': np.int64(1648),
#  'birla soft': np.int64(321),
#  'wine': np.int64(4820),
#  'thk': np.int64(4284),
#  'yup thk': np.int64(4993),
#  'need go': np.int64(2709),
#  'floor': np.int64(1365),
#  'window': np.int64(4819),
#  'shirt': np.int64(3822),
#  'sometimes': np.int64(3946),
#  'dream': np.int64(1104),
#  'without': np.int64(4840),
#  'joy': np.int64(2054),
#  'tv': np.int64(4437),
#  'become': np.int64(284),
#  'leaving': np.int64(2187),
#  'house': np.int64(1896),
#  'interview': np.int64(1994),
#  'boy': np.int64(390),
#  'missing': np.int64(2546),
#  'hello love': np.int64(1805),
#  'good boy': np.int64(1621),
#  'arrange': np.int64(175),
#  'new year': np.int64(2749),
#  'receive cash': np.int64(3543),
#  'cash holiday': np.int64(577),
#  'keep': np.int64(2072),
#  'safe': np.int64(3674),
#  'everyone': np.int64(1232),
#  'miss already': np.int64(2538),
#  'parent': np.int64(3102),
#  'hand': np.int64(1747),
#  'new job': np.int64(2734),
#  'spend': np.int64(4004),
#  'make happy': np.int64(2396),
#  'inviting': np.int64(2000),
#  'frnd': np.int64(1454),
#  'inviting friend': np.int64(2001),
#  'friend reply': np.int64(1446),
#  'reply yes': np.int64(3600),
#  'see www': np.int64(3739),
#  'www sm': np.int64(4916),
#  'stop send': np.int64(4070),
#  'send stop': np.int64(3770),
#  'stop frnd': np.int64(4068),
#  'order': np.int64(3041),
#  'content': np.int64(845),
#  'goto': np.int64(1658),
#  'internet': np.int64(1993),
#  'menu': np.int64(2482),
#  'ur mobile': np.int64(4541),
#  'module': np.int64(2586),
#  'urgent trying': np.int64(4565),
#  'wit': np.int64(4836),
#  'escape': np.int64(1207),
#  'fancy': np.int64(1272),
#  'completely': np.int64(809),
#  'form': np.int64(1390),
#  'also': np.int64(92),
#  'waste': np.int64(4704),
#  'bank': np.int64(259),
#  'hmmm': np.int64(1839),
#  'hop': np.int64(1872),
#  'muz': np.int64(2674),
#  'discus': np.int64(1054),
#  'liao': np.int64(2209),
#  'coming': np.int64(798),
#  'time coming': np.int64(4313),
#  'bloody': np.int64(346),
#  'hell': np.int64(1799),
#  'cant': np.int64(529),
#  'believe': np.int64(296),
#  ...}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
classifier.fit(X_train, y_train)

# Model Evaluation
y_pred = classifier.predict(X_test)


from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Predictions:", y_pred[:10])
print("Actual:", y_test[:10])
# Out:
# Accuracy: 0.9883408071748879
# Predictions: ['ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam']
# Actual: ['ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam']

# %%
# taking inpuut form user 

user_input = input("Enter a message: ")
user_input = re.sub('[^a-zA-Z]', ' ', user_input)
user_input = user_input.lower()
user_input = user_input.split()
user_input = [lemmatizer.lemmatize(word) for word in user_input if not word in set(stopwords.words('english'))]
user_input = ' '.join(user_input)

user_input = cv.transform([user_input]).toarray()
pred_result = classifier.predict(user_input)
print(pred_result)
# Out:
# ['ham']

# %%
#tf-idf model
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(max_features=5000,ngram_range=(1, 2))
X = cv.fit_transform(corpus).toarray()
y = data['label'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
classifier = MultinomialNB()
classifier.fit(X_train, y_train)
# Model Evaluation for TF-IDF
y_pred = classifier.predict(X_test) 
accuracy = accuracy_score(y_test, y_pred)
print("TF-IDF Accuracy:", accuracy)

print("TF-IDF Predictions:", y_pred[:10])
print("TF-IDF Actual:", y_test[:10])
# Out:
# TF-IDF Accuracy: 0.968609865470852
# TF-IDF Predictions: ['ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam']
# TF-IDF Actual: ['ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'ham' 'spam']

# %%
# !pip install gensim
import gensim
from gensim.models import Word2Vec, KeyedVectors
## References: https://stackoverflow.com/questions/46433778/import-googlenews-vectors-negative300-bin

import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']
vec_king
vec_king.shape
wv['cricket']
wv.most_similar('cricket')
wv.most_similar('happy')
wv.similarity("hockey","sports")
vec=wv['king']-wv['man']+wv['woman']
vec
wv.most_similar([vec])
